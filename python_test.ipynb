# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_table('GRACE/PAPER/Paper_Data/Hists/FitFRAP_mmh1/params.dat', names = ["a1", "a2","a3","a4","a5","a6","a7","n1","n2","u1","u2","u3"])

# %%
df['u1'] = df ['n1'] - df['n2']

# %%
params = df[df.columns[0:9]]

# %%
params
# Out:
#            a1        a2          a3            a4            a5        a6  \
# 0    0.697852  0.578100    0.922823  2.637508e+00  1.521452e+00  0.002730
# 1    0.632348  0.546651    1.328188  1.942205e+00  5.139056e-01  0.003020
# 2    0.543271  0.681680    0.946423  1.119667e+00  3.829968e+11  0.009728
# 3    0.630150  0.489495    0.659253  3.191762e+00  9.008614e+00  0.003721
# 4    0.359591  0.649785    0.945957  3.711045e-01  1.491140e+13  0.006776
# ..        ...       ...         ...           ...           ...       ...
# 107  0.631101  0.457803   62.901725  5.390059e+11  1.234449e-01  0.013232
# 108  0.696936  0.437192    2.321262  8.926655e+10  2.699355e-01  0.005239
# 109  0.433040  0.372059  109.919618  7.551973e-01  1.197173e-01  0.036899
# 110  0.629067  0.444778    0.558188  3.063039e+00  9.989088e+10  0.002336
# 111  0.698696  0.556068    0.730486  1.341012e+02  3.831397e+10  0.007808
#
#                a7        n1        n2
# 0    4.929070e-10  1.032299  1.066348
# ...
